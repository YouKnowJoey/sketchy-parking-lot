# %% [markdown]
# # Sketchy Parking Lot EDA

# %%
# Import and setup
import json
import os
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Domain parsing
import tldextract

# %% [markdown]
# ## Import Data and Preparation

# %%
'''
recursively load data
'''

data_location = 'data/parked_suspicious/'

# Load summary
with open(f"{data_location}_summary.json") as f:
    summary = json.load(f)

dfs = []

# Iterate over summary labels to combine all JSONL files
for label in summary.keys():
    clean_label = label.replace(':', '-')

    filename = f"{data_location + clean_label}.jsonl"
    
    if not os.path.exists(filename):
        print(f"Missing: {filename}")
        continue
    
    try:
        df = pd.read_json(filename, lines=True)
        dfs.append(df)
        print(f"Loaded {filename} ({len(df)} rows)")
        
    except ValueError as e:
        print(f"Error reading {filename}: {e}")

# Combine all JSONL files into single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

print("Total rows:", len(combined_df))
print("Services:", combined_df["service"].value_counts())
# Out:
# Loaded data/parked_suspicious/other-unclassified.jsonl (1000 rows)
# Loaded data/parked_suspicious/other-empty-title.jsonl (1000 rows)
# Loaded data/parked_suspicious/default-server.jsonl (1000 rows)
# Loaded data/parked_suspicious/sedo.jsonl (1000 rows)
# Loaded data/parked_suspicious/searchhounds.jsonl (1000 rows)
# Loaded data/parked_suspicious/wix-unconnected.jsonl (1000 rows)
# Loaded data/parked_suspicious/hugedomains.jsonl (1000 rows)
# Loaded data/parked_suspicious/godaddy.jsonl (1000 rows)
# Loaded data/parked_suspicious/afternic.jsonl (1000 rows)
# Loaded data/parked_suspicious/expired-domain.jsonl (1000 rows)
# Loaded data/parked_suspicious/atom.jsonl (1000 rows)
# Loaded data/parked_suspicious/spaceship.jsonl (1000 rows)
# Loaded data/parked_suspicious/other-domain-as-title.jsonl (642 rows)
# Loaded data/parked_suspicious/dynadot.jsonl (619 rows)
# Loaded data/parked_suspicious/brandbucket.jsonl (440 rows)
# Loaded data/parked_suspicious/default-nginx.jsonl (422 rows)
# Loaded data/parked_suspicious/default-apache.jsonl (348 rows)
# Loaded data/parked_suspicious/default-iis.jsonl (205 rows)
# Loaded data/parked_suspicious/other-coming-soon.jsonl (195 rows)
# Loaded data/parked_suspicious/other-expired.jsonl (159 rows)
# Loaded data/parked_suspicious/dropcatch.jsonl (154 rows)
# Loaded data/parked_suspicious/other-for-sale.jsonl (93 rows)
# Loaded data/parked_suspicious/aftermarket-pl.jsonl (70 rows)
# Loaded data/parked_suspicious/other-404.jsonl (61 rows)
# Loaded data/parked_suspicious/other-wordpress-default.jsonl (59 rows)
# Loaded data/parked_suspicious/other-account-suspended.jsonl (50 rows)
# Loaded data/parked_suspicious/other-hosting-ru.jsonl (37 rows)
# Loaded data/parked_suspicious/other-hosting-fr.jsonl (36 rows)
# Loaded data/parked_suspicious/plesk-default.jsonl (23 rows)
# Loaded data/parked_suspicious/other-welcome-to-domain.jsonl (13 rows)
# Loaded data/parked_suspicious/other-plesk.jsonl (11 rows)
# Loaded data/parked_suspicious/other-hosting-de.jsonl (9 rows)
# Loaded data/parked_suspicious/other-403.jsonl (8 rows)
# Loaded data/parked_suspicious/other-cpanel.jsonl (8 rows)
# Loaded data/parked_suspicious/other-hosting-es.jsonl (7 rows)
# Loaded data/parked_suspicious/dan.jsonl (3 rows)
# Loaded data/parked_suspicious/parkingcrew.jsonl (1 rows)
# Total rows: 15673
# Services: service
# other:unclassified         1000
# other:empty-title          1000
# default-server             1000
# sedo                       1000
# searchhounds               1000
# wix-unconnected            1000
# hugedomains                1000
# godaddy                    1000
# afternic                   1000
# expired-domain             1000
# atom                       1000
# spaceship                  1000
# other:domain-as-title       642
# dynadot                     619
# brandbucket                 440
# default-nginx               422
# default-apache              348
# default-iis                 205
# other:coming-soon           195
# other:expired               159
# dropcatch                   154
# other:for-sale               93
# aftermarket-pl               70
# other:404                    61
# other:wordpress-default      59
# other:account-suspended      50
# other:hosting-ru             37
# other:hosting-fr             36
# plesk-default                23
# other:welcome-to-domain      13
# other:plesk                  11
# other:hosting-de              9
# other:403                     8
# other:cpanel                  8
# other:hosting-es              7
# dan                           3
# parkingcrew                   1
# Name: count, dtype: int64

# %%
combined_df.head()
# Out:
#                                         url  \
# 0  http://aaa-fuerteventura-appartments.com
# 1              http://a-afolienfahrzeuge.at
# 2                  http://a-lola-estilo.com
# 3                     http://a-petrenko.com
# 4                 http://a-point-of-view.de
#
#                               domain             service  hops  \
# 0  aaa-fuerteventura-appartments.com  other:unclassified     5
# 1              a-afolienfahrzeuge.at  other:unclassified     3
# 2                  a-lola-estilo.com  other:unclassified     3
# 3                     a-petrenko.com  other:unclassified     3
# 4                 a-point-of-view.de  other:unclassified     3
#
#                                        redirectChain  \
# 0  [{'from': 'https://aaa-fuerteventura-appartmen...
# 1  [{'from': 'https://a-afolienfahrzeuge.at', 'to...
# 2  [{'from': 'https://a-lola-estilo.com', 'to': '...
# 3  [{'from': 'https://a-petrenko.com', 'to': 'htt...
# 4  [{'from': 'https://a-point-of-view.de', 'to': ...
#
#                                             finalUrl  \
# 0  https://welcome.mywebsite-editor.com/render/ww...
# 1                 https://www.a-afolienfahrzeuge.at/
# 2             https://www.a-lola-estilo.com/password
# 3                       https://a-petrenko.com/info/
# 4  https://p2m-1.forsaledomain.net/true2.php?id=a...
#
#                                title  \
# 0                     Bald verfügbar
# 1                Connect Your Domain
# 2  A Lola Estilo – Abertura em breve
# 3                         a-petrenko
# 4                   Just a moment...
#
#                                          textSnippet
# 0                                     Bald verfügbar
# 1  Connect Your Domain You're almost done! Your c...
# 2  A Lola Estilo – Abertura em breve A Lola Estil...
# 3                                         a-petrenko
# 4  Just a moment... p2m-1.forsaledomain.net Verif...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15673 entries, 0 to 15672
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            15673 non-null  object
#  1   domain         15673 non-null  object
#  2   service        15673 non-null  object
#  3   hops           15673 non-null  int64
#  4   redirectChain  15673 non-null  object
#  5   finalUrl       15673 non-null  object
#  6   title          15673 non-null  object
#  7   textSnippet    15673 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 979.7+ KB

# %%
combined_df.describe()
# Out:
#                hops
# count  15673.000000
# mean       0.710202
# std        0.998587
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max        5.000000

# %% [markdown]
# ## Text Analysis for Identification of Parked or Ad Domains

# %% [markdown]
# ## Data Wrangling
#
# Feature engineer

# %%
'''
extract TLD, domain and subdomain using tldextract

Parse the full domain for analysis.
'''
# change domain to domain_full to preserve original domain for tldextract
combined_df["domain_full"] = combined_df["domain"]
combined_df.drop("domain", axis=1, inplace=True)

def extract_domain_parts(domain):
    ext = tldextract.extract(domain)
    return pd.Series({
        "subdomain": ext.subdomain,
        "domain_name": ext.domain,
        "tld": ext.suffix
    })

combined_df[["subdomain", "domain_name", "tld"]] = combined_df["domain_full"].apply(extract_domain_parts)

# %%
'''
domain length feature

Identify how many characters the domain has.
'''
combined_df["len_domain_full"] = combined_df["domain_full"].apply(len)

# %%
'''
is_suspicious feature

This feature is derived from the amount of hops (redirects) domain has.
If a domain has more than 2 hops, we can consider it suspicious.
Subject to change based on analysis of hops distribution.
'''
threshold_hops = 2
combined_df["is_suspicious"] = combined_df["hops"].apply(lambda x: 1 if x > threshold_hops else 0)

# %%
'''
Shannons entropy of the domain feature

Calculate the Shannon entropy of the domain name to measure its randomness.
Higher entropy may indicate a more complex and potentially suspicious domain.
'''

# %%
combined_df.head()
# Out:
#                                         url             service  hops  \
# 0  http://aaa-fuerteventura-appartments.com  other:unclassified     5
# 1              http://a-afolienfahrzeuge.at  other:unclassified     3
# 2                  http://a-lola-estilo.com  other:unclassified     3
# 3                     http://a-petrenko.com  other:unclassified     3
# 4                 http://a-point-of-view.de  other:unclassified     3
#
#                                        redirectChain  \
# 0  [{'from': 'https://aaa-fuerteventura-appartmen...
# 1  [{'from': 'https://a-afolienfahrzeuge.at', 'to...
# 2  [{'from': 'https://a-lola-estilo.com', 'to': '...
# 3  [{'from': 'https://a-petrenko.com', 'to': 'htt...
# 4  [{'from': 'https://a-point-of-view.de', 'to': ...
#
#                                             finalUrl  \
# 0  https://welcome.mywebsite-editor.com/render/ww...
# 1                 https://www.a-afolienfahrzeuge.at/
# 2             https://www.a-lola-estilo.com/password
# 3                       https://a-petrenko.com/info/
# 4  https://p2m-1.forsaledomain.net/true2.php?id=a...
#
#                                title  \
# 0                     Bald verfügbar
# 1                Connect Your Domain
# 2  A Lola Estilo – Abertura em breve
# 3                         a-petrenko
# 4                   Just a moment...
#
#                                          textSnippet  \
# 0                                     Bald verfügbar
# 1  Connect Your Domain You're almost done! Your c...
# 2  A Lola Estilo – Abertura em breve A Lola Estil...
# 3                                         a-petrenko
# 4  Just a moment... p2m-1.forsaledomain.net Verif...
#
#                          domain_full subdomain                    domain_name  \
# 0  aaa-fuerteventura-appartments.com            aaa-fuerteventura-appartments
# 1              a-afolienfahrzeuge.at                       a-afolienfahrzeuge
# 2                  a-lola-estilo.com                            a-lola-estilo
# 3                     a-petrenko.com                               a-petrenko
# 4                 a-point-of-view.de                          a-point-of-view
#
#    tld  len_domain_full
# 0  com               33
# 1   at               21
# 2  com               17
# 3  com               14
# 4   de               18

# %% [markdown]
# ## Classify Based on Engineered Features
#
# Classify as parked, expired, default, or active domain.

# %% [markdown]
# ## Data Distributions and Visualizations

# %%
combined_df.columns
# Out:
# Index(['url', 'service', 'hops', 'redirectChain', 'finalUrl', 'title',
#        'textSnippet', 'domain_full', 'subdomain', 'domain_name', 'tld'],
#       dtype='object')

# %% [markdown]
# ## Save JSONL

# %%
# save as JSONL for future use

# combined_df.to_json('data/parked_suspicious/_combined_data.jsonl', orient='records', lines=True)
